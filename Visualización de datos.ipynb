# %% [markdown]
# # Visualización de datos

# %% [markdown]
# Importamos las respectivas librerias

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Lenovo/Desktop/Septimo semestre/Mineria de datos/Mall_Customers.csv",encoding='utf8')

# %%
df=df.rename(columns = {'Annual Income (k$)':'Ingresos anuales(Miles dls)','CustomerID':'ID','Gender':'Sexo','Age':'Edad','Spending Score (1-100)':'Puntaje de compras(1-100)'})

# %% [markdown]
# Renombramos las columnas para tener una mejor comprensión dado a que estan en inglés

# %%
df
# Out:
#       ID    Sexo  Edad  Ingresos anuales(Miles dls)  Puntaje de compras(1-100)
# 0      1    Male    19                           15                         39
# 1      2    Male    21                           15                         81
# 2      3  Female    20                           16                          6
# 3      4  Female    23                           16                         77
# 4      5  Female    31                           17                         40
# ..   ...     ...   ...                          ...                        ...
# 195  196  Female    35                          120                         79
# 196  197  Female    45                          126                         28
# 197  198    Male    32                          126                         74
# 198  199    Male    32                          137                         18
# 199  200    Male    30                          137                         83
#
# [200 rows x 5 columns]

# %%
df['Edad'].sum()
# Out:
# 7770

# %%
df['Edad'].mean()
# Out:
# 38.85

# %% [markdown]
# Aqui podemos observar el promedio de mis clientes dado a la muestra de 200

# %%
df['Edad'].describe()
# Out:
# count    200.000000
# mean      38.850000
# std       13.969007
# min       18.000000
# 25%       28.750000
# 50%       36.000000
# 75%       49.000000
# max       70.000000
# Name: Edad, dtype: float64

# %% [markdown]
# Gracias a esta descripción podemos observar que mi valor minimo es 18 y el valor maximo es 70

# %%
df['Puntaje de compras(1-100)'].describe()
# Out:
# count    200.000000
# mean      50.200000
# std       25.823522
# min        1.000000
# 25%       34.750000
# 50%       50.000000
# 75%       73.000000
# max       99.000000
# Name: Puntaje de compras(1-100), dtype: float64

# %% [markdown]
# Aqui podemos observar el puntaje de la media de lo que compran los clientes: 50.2, asi como el valor minimo o la compra minima de algun cliente es de 1 y la maxima de 99

# %%
df['Ingresos anuales(Miles dls)'].describe()
# Out:
# count    200.000000
# mean      60.560000
# std       26.264721
# min       15.000000
# 25%       41.500000
# 50%       61.500000
# 75%       78.000000
# max      137.000000
# Name: Ingresos anuales(Miles dls), dtype: float64

# %% [markdown]
# En esta formula podemos observar la media o en promedio lo que ganan mis clientes anualmente como podemos ver igual los minimos y maximos

# %%
df.corr()
# Out:
#                                    ID      Edad  Ingresos anuales(Miles dls)  \
# ID                           1.000000 -0.026763                     0.977548
# Edad                        -0.026763  1.000000                    -0.012398
# Ingresos anuales(Miles dls)  0.977548 -0.012398                     1.000000
# Puntaje de compras(1-100)    0.013835 -0.327227                     0.009903
#
#                              Puntaje de compras(1-100)
# ID                                            0.013835
# Edad                                         -0.327227
# Ingresos anuales(Miles dls)                   0.009903
# Puntaje de compras(1-100)                     1.000000

# %% [markdown]
# En esta grafica podemos observar que tanto se correlacionan mis datos

# %%
df.cov()
# Out:
#                                       ID        Edad  \
# ID                           3350.000000  -21.638191
# Edad                          -21.638191  195.133166
# Ingresos anuales(Miles dls)  1486.050251   -4.548744
# Puntaje de compras(1-100)      20.678392 -118.040201
#
#                              Ingresos anuales(Miles dls)  \
# ID                                           1486.050251
# Edad                                           -4.548744
# Ingresos anuales(Miles dls)                   689.835578
# Puntaje de compras(1-100)                       6.716583
#
#                              Puntaje de compras(1-100)
# ID                                           20.678392
# Edad                                       -118.040201
# Ingresos anuales(Miles dls)                   6.716583
# Puntaje de compras(1-100)                   666.854271

# %% [markdown]
# Aqui podemos observar la covarianza de los datos

# %%
df.plot.bar()

# %% [markdown]
# En esta grafica podemos observar como se comportan los datos pero a la vez no es muy visible

# %%
df['Sexo'].value_counts().plot.bar()

# %% [markdown]
# Con esta grafica de barras podemos observar que en promedio hay mas mujeres que hombres en este centro comercial

# %%
df.plot.bar(x='Sexo', y='Puntaje de compras(1-100)')

# %% [markdown]
# En esta grafia queriamos apreciar quienes eran los que compraban mas en el centro comercial pero como podemos ver no se alcanza a notar

# %%
df.plot.line(x='Edad', y='Puntaje de compras(1-100)')

# %% [markdown]
# En esta grafica queriamos ver si la edad influia en respecto al puntaje de compras pero como podemos apreciar no es muy visible cuando se pide una grafica alineada

# %%
df.plot.bar(x='Edad', y='Puntaje de compras(1-100)')

# %% [markdown]
# En esta otra queriamos ver lo mismo sobre la edad pero como se puede observar tampoco se logra apreciar

# %%
df.plot.line(x='Sexo', y='Puntaje de compras(1-100)')

# %%
df.plot.line(x='Edad', y='Ingresos anuales(Miles dls)')

# %%
df.plot.bar(x='Edad', y='Ingresos anuales(Miles dls)')

# %% [markdown]
# Basicamente la mayoria salieron mal dado a que eran bastantes datos y no se lograba apreciar lo que decia el eje x

# %%
df['Edad'].value_counts().sort_index().plot.area()

# %% [markdown]
# En esta grafica si pudimos apreciar muy bien la cantidad de personas que hay y como podemos notar es mas gente joven, por lo que es un gran punto para nuestro objetivo, dado a que queremos ver cual es el mercado o cliente objetivo

# %%
df['Edad'].value_counts().sort_index().plot.line()

# %% [markdown]
# Misma grafica sin area

# %%
df['Edad'].plot.hist()

# %% [markdown]
# Y aqui estamos viendo lo mismo solo que de una forma mas concreta usando histogramas.
# Podemos concluir que hay mas personas entre 30 y 40

# %% [markdown]
# ## Graficar datos bi-variantes.

# %%
df[df['Edad']<200].sample(200).plot.scatter(x='Edad', y='Ingresos anuales(Miles dls)')

# %% [markdown]
# En esta grafica queriamos ver donde estaban mas concentrados nuestros datos en cuanto a los ingresos anuales de mis clientes dado a que queremos ver si eso influye o no en cuanto a la hora de comprar en nuestro centro comercial

# %%
df[df['Edad'] < 200].plot.hexbin(x='Edad', y='Ingresos anuales(Miles dls)', gridsize=5)

# %% [markdown]
# En esta grafica podemos observar lo mismo pero un poco mas ilustrado

# %%
df[df['Edad'] < 200].plot.scatter(x='Edad', y='Puntaje de compras(1-100)')

# %% [markdown]
# En esta grafica queremos ver en donde esta concentrado el puntaje de compras conforme a la edad

# %%
df[df['Edad'] < 200].plot.hexbin(x='Edad', y='Puntaje de compras(1-100)', gridsize=5)

# %% [markdown]
# Aqui lo mismo pero mas ilustrado

# %%
sns.pairplot(df[['Edad', 'Puntaje de compras(1-100)']])

# %%
df.plot.bar(stacked=True)

# %% [markdown]
# ## Box plots y grafica de violin

# %%
datf = df[df.Sexo.isin(df.Sexo.value_counts().head().index)]

sns.boxplot(
    x='Sexo',
    y='Puntaje de compras(1-100)',
    data=datf
)

# %% [markdown]
# Gracias a esta grafica de Boxplot podemos concluir que las mujeres gastan un poco mas que los hombres en promedio

# %%
dati = df[df.Sexo.isin(df.Sexo.value_counts().head().index)]

sns.boxplot(
    x='Sexo',
    y='Ingresos anuales(Miles dls)',
    data=dati
)

# %% [markdown]
# Y gracias a esta otra podemos observar que los hombres ganan un poco mas que las mujeres anualmente

# %%
sns.violinplot(
    x='Sexo',
    y='Ingresos anuales(Miles dls)',
    data=df[df.Sexo.isin(df.Sexo.value_counts()[:2].index)]
)

# %%
sns.violinplot(
    x='Sexo',
    y='Puntaje de compras(1-100)',
    data=df[df.Sexo.isin(df.Sexo.value_counts()[:2].index)]
)

# %% [markdown]
# Y aqui nuestras graficas de violin que practicamente dicen lo mismo

# %% [markdown]
# ## Multi-variante

# %%
import seaborn as sns
import matplotlib.pyplot as plt
f,ax=plt.subplots(figsize = (4,4))
sns.heatmap(df.corr(),annot= True,linewidths=0.5,fmt = ".1f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# Aqui nuestra grafica de correlacion podemos ver que el Id se relaciona mucho con los ingresos pero esto es porque estan ordenados de menor a mayor asi que descartamos esa opcion dado a que no nos proporciona nada

# %%
sns.lmplot(x='Edad', y='Puntaje de compras(1-100)', hue='Sexo', 
           data=df.loc[df['Sexo'].isin(['Male', 'Female'])], 
           fit_reg=False)

# %% [markdown]
# Con esta grafica Multivariante podemos ver que nuestro mercado objetivo podria localizarse entre la edad de 20 y 40 años

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for x in ['Edad' , 'Ingresos anuales(Miles dls)' , 'Puntaje de compras(1-100)']:
    for y in ['Edad' , 'Ingresos anuales(Miles dls)' , 'Puntaje de compras(1-100)']:
        n += 1
        plt.subplot(3 , 3 , n)
        plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
        sns.regplot(x = x , y = y , data = df)
        plt.ylabel(y.split()[0]+' '+y.split()[1] if len(y.split()) > 1 else y )
plt.show()

# %% [markdown]
# Estas ultimas graficas nos indican mas a fondo si mis datos se relacionan o no y por lo que podemos observar no se relacionan mucho.
# Lo unico recatable de aqui serian la edad e ingresos anuales aunque no se relacionen tanto y tambien podemos descartar que la edad no influye en el puntaje de las compras dado a que su pendiente es negativa.

# %% [markdown]
# Y como conclusion creo que es importante acomodar los datos en mi base de datos haciendo enfasis en la columna de edades dado a que estan desacomodadas y creo que tambien seria necesario quitar la columna ID debido a que no nos aporta nada a nuestros objetivos.

# %% [markdown]
# # Tablas extras que encontré

# %%
plt.figure(1 , figsize = (15 , 6))
for Sexo in ['Male' , 'Female']:
    plt.scatter(x = 'Edad' , y = 'Ingresos anuales(Miles dls)' , data = df[df['Sexo'] == Sexo] ,
                s = 200 , alpha = 0.5 , label = Sexo)
plt.xlabel('Edad'), plt.ylabel('Ingresos anuales(Miles dls)') 
plt.title('Edad vs Ingresos anuales con Genero')
plt.legend()
plt.show()

# %%
plt.figure(1 , figsize = (15 , 6))
for sexo in ['Male' , 'Female']:
    plt.scatter(x = 'Ingresos anuales(Miles dls)',y = 'Puntaje de compras(1-100)' ,
                data = df[df['Sexo'] == sexo] ,s = 200 , alpha = 0.5 , label = sexo)
plt.xlabel('Ingresos anuales(Miles dls)'), plt.ylabel('Puntaje de compras(1-100)') 
plt.title('Ingresos Anuales vs Puntajes de compras con Genero')
plt.legend()
plt.show()

# %%
plt.figure(1 , figsize = (15 , 6))
for sexo in ['Male' , 'Female']:
    plt.scatter(x = 'Edad',y = 'Puntaje de compras(1-100)' ,
                data = df[df['Sexo'] == sexo] ,s = 200 , alpha = 0.5 , label = sexo)
plt.xlabel('Edad'), plt.ylabel('Puntaje de compras(1-100)') 
plt.title('Edad vs Puntajes de compras con Genero')
plt.legend()
plt.show()

# %% [markdown]
# Gracias a estas graficas creo que se pudo entender mejor el objetivo, dado a que nos dice casi todo y puedo concluir que:
# **1.-**Los jovenes tienen mejor ingreso anual que los adultos gracias a la primer grafica
# **2.-**Mis clientes objetivo son de clase media dado a que los puntos se concentran entre el 40-70 de la segunda grafica
# **3.-**Los jovenes son los que mas gastan
